# %%
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
job_India = df[df['job_country'] == 'India'].copy()

# %%
job_India['job_posted_month'] = job_India['job_posted_date'].dt.strftime('%B')

# %%
job_pivot = job_India.pivot_table(
 index='job_posted_month',
 columns='job_title_short',
 aggfunc='size'
)

# %%
job_pivot.reset_index(inplace=True)
job_pivot['month_no'] = pd.to_datetime(job_pivot['job_posted_month'], format = '%B').dt.month
job_pivot.sort_values('month_no')
# Out:
# job_title_short job_posted_month  Business Analyst  Cloud Engineer  \
# 4                        January               175              31
# 3                       February               143              35
# 7                          March               116              37
# 0                          April               170              32
# 8                            May               103              14
# 6                           June               146              26
# 5                           July               142              25
# 1                         August               189              25
# 11                     September               155              34
# 10                       October               170              36
# 9                       November               192              29
# 2                       December               186              27
#
# job_title_short  Data Analyst  Data Engineer  Data Scientist  \
# ...

# %%
job_pivot.set_index('job_posted_month', inplace=True)

# %%
job_pivot
# Out:
# job_title_short job_posted_month  Business Analyst  Cloud Engineer  \
# 0                          April               170              32
# 1                         August               189              25
# 2                       December               186              27
# 3                       February               143              35
# 4                        January               175              31
# 5                           July               142              25
# 6                           June               146              26
# 7                          March               116              37
# 8                            May               103              14
# 9                       November               192              29
# 10                       October               170              36
# 11                     September               155              34
#
# job_title_short  Data Analyst  Data Engineer  Data Scientist  \
# ...

# %%
job_pivot = job_pivot.sort_values(by='month_no')

# %%
job_pivot.drop('month_no', axis=1, inplace=True)

# %%
job_pivot
# Out:
# job_title_short job_posted_month  Business Analyst  Cloud Engineer  \
# 4                        January               175              31
# 3                       February               143              35
# 7                          March               116              37
# 0                          April               170              32
# 8                            May               103              14
# 6                           June               146              26
# 5                           July               142              25
# 1                         August               189              25
# 11                     September               155              34
# 10                       October               170              36
# 9                       November               192              29
# 2                       December               186              27
#
# job_title_short  Data Analyst  Data Engineer  Data Scientist  \
# ...

# %%
job_pivot.set_index('job_posted_month', inplace=True)

# %%
job_pivot
# Out:
# job_title_short   Business Analyst  Cloud Engineer  Data Analyst  \
# job_posted_month
# January                        175              31           628
# February                       143              35           433
# March                          116              37           422
# April                          170              32           418
# May                            103              14           278
# June                           146              26           367
# July                           142              25           457
# August                         189              25           618
# September                      155              34           630
# October                        170              36           500
# November                       192              29           722
# December                       186              27           648
#
# job_title_short   Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_posted_month
# ...

# %%
job_pivot[top_3.index.to_list()].plot(kind='line')
plt.title('Monthly job Posting for Top Job in India')
plt.xlabel('2023')
plt.ylabel('Job count')
plt.legend()
plt.show()

# %%
techjob_India = pd.read_csv('https://lukeb.co/software_csv', index_col='job_posted_month')
techjob_India
# Out:
#                   Front-End Developer  Back-End Developer  \
# job_posted_month
# January                         13619                9827
# February                        11456                9116
# March                           11102                8178
# April                           14037                9209
# May                             12126                8864
# June                            12003                8065
# July                            11914                8061
# August                          11571                8191
# September                       14016                8447
# October                         11419                8476
# November                        13771                9034
# December                        14033                9232
#
#                   Full-Stack Developer  UI/UX Designer
# job_posted_month
# January                           5108            4348
# February                          7298            4284
# ...

# %%
job_merged = job_pivot.merge(techjob_India, on='job_posted_month')

# %%
top_5_jobs = job_merged.sum().sort_values(ascending = False).head(5).index.to_list()
top_5_jobs
# Out:
# ['Front-End Developer',
#  'Back-End Developer',
#  'Full-Stack Developer',
#  'UI/UX Designer',
#  'Data Engineer']

# %%
job_merged[top_5_jobs].plot(kind='line')
plt.title('Monthly job Posting for Top Job in India')
plt.xlabel('2023')
plt.ylabel('Job count')
plt.ylim(0,20000)
plt.legend()
plt.show()
