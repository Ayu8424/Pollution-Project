# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

coffee = pd.read_csv('https://raw.githubusercontent.com/KeithGalli/complete-pandas-tutorial/refs/heads/master/warmup-data/coffee.csv')

# %%
olympics_data = pd.read_excel(r"C:\Users\AYAN SHAIKH\Downloads\olympics-data (1).xlsx")

# %%
result = pd.read_parquet('https://raw.githubusercontent.com/KeithGalli/complete-pandas-tutorial/refs/heads/master/data/results.parquet')

# %%
bios = pd.read_csv('https://raw.githubusercontent.com/KeithGalli/complete-pandas-tutorial/refs/heads/master/data/bios.csv')

# %%
coffee.head(5)
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
olympics_data.head(5)
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
result.head(5)
# Out:
#      year    type discipline                     event                     as  \
# 0  1912.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 1  1912.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
# 2  1920.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 3  1920.0  Summer     Tennis  Doubles, Mixed (Olympic)  Jean-François Blanchy
# 4  1920.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
#
#    athlete_id  noc             team  place   tied medal
# 0           1  FRA             None   17.0   True  None
# 1           1  FRA   Jean Montariol    NaN  False  None
# 2           1  FRA             None   32.0   True  None
# 3           1  FRA  Jeanne Vaussard    8.0   True  None
# 4           1  FRA  Jacques Brugnon    4.0  False  None

# %%
coffee.sample(5,random_state=1)
# Out:
#          Day Coffee Type  Units Sold
# 3    Tuesday       Latte          20
# 7   Thursday       Latte          30
# 6   Thursday    Espresso          40
# 2    Tuesday    Espresso          30
# 10  Saturday    Espresso          45

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
coffee.loc[[0,5]]
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 5  Wednesday       Latte          25

# %%
coffee.loc[:,["Day", "Units Sold"]]
# Out:
#           Day  Units Sold
# 0      Monday          25
# 1      Monday          15
# 2     Tuesday          30
# 3     Tuesday          20
# 4   Wednesday          35
# 5   Wednesday          25
# 6    Thursday          40
# 7    Thursday          30
# 8      Friday          45
# 9      Friday          35
# 10   Saturday          45
# 11   Saturday          35
# 12     Sunday          45
# 13     Sunday          35

# %%
# coffee.index = coffee["Day"]

# %%
coffee.loc['Monday']
# Out:
#            Day Coffee Type  Units Sold
# Day
# Monday  Monday    Espresso          25
# Monday  Monday       Latte          10

# %%
coffee.loc['Monday':'Wednesday','Units Sold']
# Out:
# Day
# Monday       25
# Monday       10
# Tuesday      10
# Tuesday      10
# Wednesday    35
# Wednesday    25
# Name: Units Sold, dtype: int64

# %%
coffee.head()
# Out:
#                  Day Coffee Type  Units Sold
# Day
# Monday        Monday    Espresso          25
# Monday        Monday       Latte          10
# Tuesday      Tuesday    Espresso          10
# Tuesday      Tuesday       Latte          10
# Wednesday  Wednesday    Espresso          35

# %%
coffee['Units Sold']
# Out:
# Day
# Monday       25
# Monday       10
# Tuesday      10
# Tuesday      10
# Wednesday    35
# Wednesday    25
# Thursday     40
# Thursday     30
# Friday       45
# Friday       35
# Saturday     45
# Saturday     35
# Sunday       45
# Sunday       35
# Name: Units Sold, dtype: int64

# %%
coffee.sort_values(["Units Sold", "Coffee Type"], ascending=False)
# Out:
#                  Day Coffee Type  Units Sold
# Day
# Friday        Friday    Espresso          45
# Saturday    Saturday    Espresso          45
# Sunday        Sunday    Espresso          45
# Thursday    Thursday    Espresso          40
# Friday        Friday       Latte          35
# Saturday    Saturday       Latte          35
# Sunday        Sunday       Latte          35
# Wednesday  Wednesday    Espresso          35
# Thursday    Thursday       Latte          30
# Wednesday  Wednesday       Latte          25
# Monday        Monday    Espresso          25
# Monday        Monday       Latte          10
# Tuesday      Tuesday       Latte          10
# Tuesday      Tuesday    Espresso          10

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
bios.tail()
# Out:
#         athlete_id                 name   born_date        born_city  \
# 145495      149222    Polina Luchnikova  2002-01-30            Serov
# 145496      149223  Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224      Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225       André Foussard  1899-05-19            Niort
# 145499      149814        Bill Phillips  1913-07-15     Dulwich Hill
#
#             born_region born_country        NOC  height_cm  weight_kg  \
# 145495       Sverdlovsk          RUS        ROC      167.0       61.0
# 145496           Moskva          RUS        ROC      168.0       65.0
# 145497      Arkhangelsk          RUS        ROC      163.0       55.0
# 145498      Deux-Sèvres          FRA     France      166.0        NaN
# 145499  New South Wales          AUS  Australia        NaN        NaN
#
#          died_date
# 145495         NaN
# 145496         NaN
# 145497         NaN
# 145498  1986-03-18
# 145499  2003-10-20

# %%
bios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145500 entries, 0 to 145499
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   athlete_id    145500 non-null  int64
#  1   name          145500 non-null  object
#  2   born_date     143693 non-null  object
#  3   born_city     110908 non-null  object
#  4   born_region   110908 non-null  object
#  5   born_country  110908 non-null  object
#  6   NOC           145499 non-null  object
#  7   height_cm     106651 non-null  float64
#  8   weight_kg     102070 non-null  float64
#  9   died_date     33940 non-null   object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 11.1+ MB

# %%
bios.loc[bios['height_cm'] > 215, ['name', 'height_cm']]
# Out:
#                          name  height_cm
# 5089       Viktor Pankrashkin      220.0
# 5583     Paulinho Villas Boas      217.0
# 5673           Gunther Behnke      221.0
# 5716                 Uwe Blab      218.0
# 5781           Tommy Burleson      223.0
# 5796            Andy Campbell      218.0
# 6223              Lars Hansen      216.0
# 6270              Hu Zhangbao      216.0
# 6409         Sergey Kovalenko      216.0
# 6420            Jānis Krūmiņš      218.0
# 6504              Luc Longley      220.0
# 6722         Shaquille O'Neal      216.0
# 6937           David Robinson      216.0
# 6978          Arvydas Sabonis      223.0
# 7074           Paulo da Silva      217.0
# 7188       Vladimir Tkachenko      220.0
# 7281         Stojko Vranković      217.0
# 7376      Eurelijus Žukauskas      218.0
# 52608         Aleksey Kazakov      217.0
# 82100           Frédéric Weis      218.0
# 89070                Yao Ming      226.0
# 89075          Roberto Dueñas      221.0
# ...

# %%
bios[(bios['height_cm'] > 215) & (bios['born_country'] == 'USA')]
# Out:
#         athlete_id              name   born_date  born_city     born_region  \
# 5781          5804    Tommy Burleson  1952-02-24  Crossnore  North Carolina
# 6722          6755  Shaquille O'Neal  1972-03-06     Newark      New Jersey
# 6937          6972    David Robinson  1965-08-06   Key West         Florida
# 123850      126093    Tyson Chandler  1982-10-02    Hanford      California
#
#        born_country            NOC  height_cm  weight_kg died_date
# 5781            USA  United States      223.0      102.0       NaN
# 6722            USA  United States      216.0      137.0       NaN
# 6937            USA  United States      216.0      107.0       NaN
# 123850          USA  United States      216.0      107.0       NaN

# %%
bios[bios['name'].str.contains('Ayan')]
# bios[bios['name'].str.contains('Ayan', case=False)]
# Out:
#         athlete_id               name   born_date      born_city  \
# 33185        33437      Alpaslan Ayan  1966-05-04            NaN
# 46940        47289        Ayano Egami  1980-04-01            NaN
# 52149        52514      Ayano Shibuki  1941-03-29          Okaya
# 73388        73953    Gloria Ayanlaja  1956-05-12            NaN
# 88330        89038  Ayanna Hutchinson  1978-02-18            NaN
# 118821      120577        Ayano Kishi  1992-10-29      Musashino
# 123734      125960   Ayanna Alexander  1982-07-20  Port of Spain
# 125638      127983      Ayana Onozuka  1988-03-23   Minamiuonuma
# 127570      130029        Almaz Ayana  1991-11-21            NaN
# 128245      130763     Ayane Kurihara  1989-09-27     Kitakyushu
# 130774      133517  Ayanleh Souleiman  1992-12-03       Djibouti
# 134428      137491         Ayano Sato  1996-12-10        Kushiro
# 135246      138397      Ayana Zholdas  2001-06-09            NaN
# ...

# %%
bios[bios['born_country'].isin(['USA','FRA','GBR']) & (bios['name'].str.startswith('Keith'))]
# Out:
#         athlete_id                name   born_date             born_city  \
# 3505          3517       Keith Wallace  1961-03-29               Preston
# 12053        12118        Keith Hervey  1898-11-03                Fulham
# 14577        14674      Keith Harrison  1933-03-28            Birmingham
# 16166        16281      Keith Reynolds  1963-12-25              Solihull
# 18734        18862      Keith Sinclair  1945-06-26            Sunderland
# 29897        30123       Keith Langley  1961-06-03             Aldershot
# 34011        34275        Keith Remfry  1947-11-17                Ealing
# 46885        47234        Keith Collin  1937-01-18            Marylebone
# 50929        51288        Keith Carter  1924-08-30                 Akron
# 51185        51544       Keith Russell  1948-01-15                  Mesa
# 52913        53288      Keith Erickson  1944-04-19         San Francisco
# 55317        55712        Keith Boxell  1958-05-06               Clapham
# ...

# %% [markdown]
# IF you want to avoid writing bios for many time, use query function. The example is above.

# %%
bios.query('born_country == "USA" and born_city == "Chicago"')
# Out:
#         athlete_id                 name   born_date born_city born_region  \
# 1989          1999      Rafael Aveleyra  1932-07-29   Chicago    Illinois
# 2765          2777           John Neely  1872-05-26   Chicago    Illinois
# 3245          3257         Craig Wilson  1970-09-03   Chicago    Illinois
# 5175          5194       Cynthia Cooper  1963-04-14   Chicago    Illinois
# 5318          5337      Charlotte Lewis  1955-09-10   Chicago    Illinois
# ...            ...                  ...         ...       ...         ...
# 143542      147195     Nefeli Papadakis  1998-10-02   Chicago    Illinois
# 143559      147212      Evita Griskenas  2000-12-03   Chicago    Illinois
# 143656      147310  Tamyra Mensah-Stock  1992-10-11   Chicago    Illinois
# 143749      147404      Adrian Hegyvary  1984-01-05   Chicago    Illinois
# 144399      148089      Kailiaosi Jieke  1991-03-08   Chicago    Illinois
#
#        born_country                         NOC  height_cm  weight_kg  \
# ...

# %% [markdown]
# How to Add or Remove Coloumn. We can understand with the following example.

# %%
coffee['price'] = 4.99 #this is how you can create the column

# %%
coffee['new_price'] = np.where(coffee['Coffee Type'] == 'Espresso', 3.99,5.99)

# %%
coffee.head()
# Out:
#                  Day Coffee Type  Units Sold  price  new_price
# Day
# Monday        Monday    Espresso          25   4.99       3.99
# Monday        Monday       Latte          10   4.99       5.99
# Tuesday      Tuesday    Espresso          10   4.99       3.99
# Tuesday      Tuesday       Latte          10   4.99       5.99
# Wednesday  Wednesday    Espresso          35   4.99       3.99

# %%
coffee.drop(columns=['price'],inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[157], line 1
# ----> 1 coffee.drop(columns=['price'],inplace=True)
#
# File c:\Users\AYAN SHAIKH\anaconda3\envs\PYTHON_DATA_PROJECT\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
# ...

# %%
coffee
# Out:
#                  Day Coffee Type  Units Sold  new_price
# Day
# Monday        Monday    Espresso          25       3.99
# Monday        Monday       Latte          10       5.99
# Tuesday      Tuesday    Espresso          10       3.99
# Tuesday      Tuesday       Latte          10       5.99
# Wednesday  Wednesday    Espresso          35       3.99
# Wednesday  Wednesday       Latte          25       5.99
# Thursday    Thursday    Espresso          40       3.99
# Thursday    Thursday       Latte          30       5.99
# Friday        Friday    Espresso          45       3.99
# Friday        Friday       Latte          35       5.99
# Saturday    Saturday    Espresso          45       3.99
# Saturday    Saturday       Latte          35       5.99
# Sunday        Sunday    Espresso          45       3.99
# Sunday        Sunday       Latte          35       5.99

# %%
coffee.drop(columns=['new_price'],inplace=True)

# %%
coffee_new = coffee.copy()
coffee_new['price'] = 4.99

# %%
coffee_new
# Out:
#                  Day Coffee Type  Units Sold  price
# Day
# Monday        Monday    Espresso          25   4.99
# Monday        Monday       Latte          10   4.99
# Tuesday      Tuesday    Espresso          10   4.99
# Tuesday      Tuesday       Latte          10   4.99
# Wednesday  Wednesday    Espresso          35   4.99
# Wednesday  Wednesday       Latte          25   4.99
# Thursday    Thursday    Espresso          40   4.99
# Thursday    Thursday       Latte          30   4.99
# Friday        Friday    Espresso          45   4.99
# Friday        Friday       Latte          35   4.99
# Saturday    Saturday    Espresso          45   4.99
# Saturday    Saturday       Latte          35   4.99
# Sunday        Sunday    Espresso          45   4.99
# Sunday        Sunday       Latte          35   4.99

# %%
coffee.drop(columns=['price'],inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[165], line 1
# ----> 1 coffee.drop(columns=['price'],inplace=True)
#
# File c:\Users\AYAN SHAIKH\anaconda3\envs\PYTHON_DATA_PROJECT\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
# ...

# %%
coffee['new_price'] = np.where(coffee['Coffee Type'] == 'Espresso', 3.99,5.99)

# %%
coffee
# Out:
#                  Day Coffee Type  Units Sold  new_price
# Day
# Monday        Monday    Espresso          25       3.99
# Monday        Monday       Latte          10       5.99
# Tuesday      Tuesday    Espresso          10       3.99
# Tuesday      Tuesday       Latte          10       5.99
# Wednesday  Wednesday    Espresso          35       3.99
# Wednesday  Wednesday       Latte          25       5.99
# Thursday    Thursday    Espresso          40       3.99
# Thursday    Thursday       Latte          30       5.99
# Friday        Friday    Espresso          45       3.99
# Friday        Friday       Latte          35       5.99
# Saturday    Saturday    Espresso          45       3.99
# Saturday    Saturday       Latte          35       5.99
# Sunday        Sunday    Espresso          45       3.99
# Sunday        Sunday       Latte          35       5.99

# %%
coffee = coffee[['Day','Coffee Type','Units Sold','new_price']]

# %%
coffee['revenue'] = coffee['Units Sold'] * coffee['new_price']

# %%
coffee
# Out:
#                  Day Coffee Type  Units Sold  new_price  revenue
# Day
# Monday        Monday    Espresso          25       3.99    99.75
# Monday        Monday       Latte          10       5.99    59.90
# Tuesday      Tuesday    Espresso          10       3.99    39.90
# Tuesday      Tuesday       Latte          10       5.99    59.90
# Wednesday  Wednesday    Espresso          35       3.99   139.65
# Wednesday  Wednesday       Latte          25       5.99   149.75
# Thursday    Thursday    Espresso          40       3.99   159.60
# Thursday    Thursday       Latte          30       5.99   179.70
# Friday        Friday    Espresso          45       3.99   179.55
# Friday        Friday       Latte          35       5.99   209.65
# Saturday    Saturday    Espresso          45       3.99   179.55
# Saturday    Saturday       Latte          35       5.99   209.65
# Sunday        Sunday    Espresso          45       3.99   179.55
# ...

# %%
coffee.rename(columns={'new_price':'price'})
# Out:
#                  Day Coffee Type  Units Sold  price  revenue
# Day
# Monday        Monday    Espresso          25   3.99    99.75
# Monday        Monday       Latte          10   5.99    59.90
# Tuesday      Tuesday    Espresso          10   3.99    39.90
# Tuesday      Tuesday       Latte          10   5.99    59.90
# Wednesday  Wednesday    Espresso          35   3.99   139.65
# Wednesday  Wednesday       Latte          25   5.99   149.75
# Thursday    Thursday    Espresso          40   3.99   159.60
# Thursday    Thursday       Latte          30   5.99   179.70
# Friday        Friday    Espresso          45   3.99   179.55
# Friday        Friday       Latte          35   5.99   209.65
# Saturday    Saturday    Espresso          45   3.99   179.55
# Saturday    Saturday       Latte          35   5.99   209.65
# Sunday        Sunday    Espresso          45   3.99   179.55
# Sunday        Sunday       Latte          35   5.99   209.65

# %%
bio_new = bios

# %%
bio_new.head(5)
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
bio_new['first_name'] = bio_new['name'].str.split(' ').str[0]

# %%
bio_new.query('first_name == "Keith"')
# Out:
#         athlete_id               name   born_date     born_city  \
# 1897          1907       Keith Hanlon  1966-09-01           NaN
# 3505          3517      Keith Wallace  1961-03-29       Preston
# 6228          6255      Keith Hartley  1940-10-15     Vancouver
# 8898          8946        Keith Mwila  1966-01-01           NaN
# 12053        12118       Keith Hervey  1898-11-03        Fulham
# ...            ...                ...         ...           ...
# 99921       100722       Keith Carney  1970-02-03    Providence
# 102227      103168      Keith Beavers  1983-02-09        London
# 109900      111105  Keith Cumberpatch  1927-08-25  Christchurch
# 115973      117348    Keith Sanderson  1975-02-02      Plymouth
# 122121      124176     Keith Ferguson  1979-09-07          Sale
#
#              born_region born_country            NOC  height_cm  weight_kg  \
# 1897                 NaN          NaN        Ireland        NaN        NaN
# ...

# %%
bio_new['born_datetime'] = pd.to_datetime(bio_new['born_date'], format = '%Y-%m-%d')

# %%
bio_new
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# ...

# %%
bio_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145500 entries, 0 to 145499
# Data columns (total 13 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   athlete_id     145500 non-null  int64
#  1   name           145500 non-null  object
#  2   born_date      143693 non-null  object
#  3   born_city      110908 non-null  object
#  4   born_region    110908 non-null  object
#  5   born_country   110908 non-null  object
#  6   NOC            145499 non-null  object
#  7   height_cm      106651 non-null  float64
#  8   weight_kg      102070 non-null  float64
#  9   died_date      33940 non-null   object
#  10  first_name     145500 non-null  object
#  11  born_datetime  143693 non-null  datetime64[ns]
#  12  born_year      143693 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(1), object(8)
# memory usage: 14.4+ MB

# %%
bio_new['born_year'] = bio_new['born_datetime'].dt.year

# %%
bio_new[['name','born_year']]
# Out:
#                          name  born_year
# 0       Jean-François Blanchy     1886.0
# 1              Arnaud Boetsch     1969.0
# 2                Jean Borotra     1898.0
# 3             Jacques Brugnon     1895.0
# 4                Albert Canet     1878.0
# ...                       ...        ...
# 145495      Polina Luchnikova     2002.0
# 145496    Valeriya Merkusheva     1999.0
# 145497        Yuliya Smirnova     1998.0
# 145498         André Foussard     1899.0
# 145499          Bill Phillips     1913.0
#
# [145500 rows x 2 columns]

# %%
bio_new['height_category'] = bio_new['height_cm'].apply(lambda x: 'short' if x < 165 else ('Average' if x < 185 else 'Tall'))

# %%
bio_new.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date     first_name born_datetime  born_year height_category
# 0  1960-10-02  Jean-François    1886-12-12     1886.0            Tall
# ...

# %%
nocs = pd.read_csv('https://raw.githubusercontent.com/KeithGalli/complete-pandas-tutorial/refs/heads/master/data/noc_regions.csv')

# %%
nocs.head()
# Out:
#    NOC       region                 notes
# 0  AFG  Afghanistan                   NaN
# 1  AHO      Curacao  Netherlands Antilles
# 2  ALB      Albania                   NaN
# 3  ALG      Algeria                   NaN
# 4  AND      Andorra                   NaN

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date     first_name born_datetime  born_year height_category
# 0  1960-10-02  Jean-François    1886-12-12     1886.0            Tall
# ...

# %%
bios_new = pd.merge(bios,nocs, left_on = 'born_country', right_on = 'NOC', how='left')

# %%
bios_new.rename(columns={'region':'born_country_full'},inplace=True)

# %%
bios_new.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country   NOC_x  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date     first_name born_datetime  born_year height_category NOC_y  \
# 0  1960-10-02  Jean-François    1886-12-12     1886.0            Tall   FRA
# ...

# %%
bios_new[bios_new['NOC_x'] != bios_new['born_country_full']][['NOC_x','born_country_full']]
# Out:
#           NOC_x born_country_full
# 4        France                UK
# 12       France               NaN
# 13       France               NaN
# 16       France           Morocco
# 27       France               NaN
# ...         ...               ...
# 145491  Jamaica               NaN
# 145493      ROC            Russia
# 145495      ROC            Russia
# 145496      ROC            Russia
# 145497      ROC            Russia
#
# [73210 rows x 2 columns]

# %%
usa = bios_new[bios_new['born_country'] == 'USA'].copy()
gbr = bios_new[bios_new['born_country'] == 'GBR'].copy()

# %%
usa.head()
# Out:
#       athlete_id               name   born_date         born_city born_region  \
# 54            55      Monique Javer  1967-07-22        Burlingame  California
# 960          964   Xóchitl Escobedo  1968-09-17       West Covina  California
# 961          965  Angélica Gavaldón  1973-10-03         El Centro  California
# 1231        1238     Bert Schneider  1897-07-01         Cleveland        Ohio
# 1345        1352         Laura Berg  1975-01-06  Santa Fe Springs  California
#
#      born_country          NOC_x  height_cm  weight_kg   died_date first_name  \
# 54            USA  Great Britain      177.0       64.0         NaN    Monique
# 960           USA         Mexico      170.0       60.0         NaN    Xóchitl
# 961           USA         Mexico      160.0       54.0         NaN   Angélica
# 1231          USA         Canada        NaN        NaN  1986-02-20       Bert
# 1345          USA  United States      168.0       61.0         NaN      Laura
#
# ...

# %%
gbr.head()
# Out:
#     athlete_id               name   born_date    born_city born_region  \
# 4            5       Albert Canet  1878-04-17   Wandsworth     England
# 37          38    Helen Aitchison  1881-12-06   Sunderland     England
# 38          39  Geraldine Beamish  1883-06-23  Forest Gate     England
# 39          40       Dora Boothby  1881-08-02     Finchley     England
# 40          41     Julie Bradbury  1967-02-12       Oxford     England
#
#    born_country          NOC_x  height_cm  weight_kg   died_date first_name  \
# 4           GBR         France        NaN        NaN  1930-07-25     Albert
# 37          GBR  Great Britain        NaN        NaN  1947-05-26      Helen
# 38          GBR  Great Britain        NaN        NaN  1972-05-10  Geraldine
# 39          GBR  Great Britain        NaN        NaN  1970-02-22       Dora
# 40          GBR  Great Britain      175.0       64.0         NaN      Julie
#
#    born_datetime  born_year height_category NOC_y born_country_full notes
# ...

# %%
new_df = pd.concat([usa,gbr])

# %%
new_df.tail()
# Out:
#         athlete_id                name   born_date     born_city born_region  \
# 144811      148512  Benjamin Alexander  1983-05-08        London     England
# 144815      148517       Ashley Watson  1993-10-28  Peterborough     England
# 145005      148716     Peder Kongshaug  2001-08-13     Wimbledon     England
# 145319      149041          Axel Brown  1992-04-02     Harrogate     England
# 145388      149111      Jean-Luc Baker  1993-10-07       Burnley     England
#
#        born_country                NOC_x  height_cm  weight_kg died_date  \
# 144811          GBR              Jamaica        NaN        NaN       NaN
# 144815          GBR              Jamaica        NaN        NaN       NaN
# 145005          GBR               Norway      184.0       86.0       NaN
# 145319          GBR  Trinidad and Tobago        NaN        NaN       NaN
# 145388          GBR        United States        NaN        NaN       NaN
#
# ...

# %%
new_df.head()
# Out:
#       athlete_id               name   born_date         born_city born_region  \
# 54            55      Monique Javer  1967-07-22        Burlingame  California
# 960          964   Xóchitl Escobedo  1968-09-17       West Covina  California
# 961          965  Angélica Gavaldón  1973-10-03         El Centro  California
# 1231        1238     Bert Schneider  1897-07-01         Cleveland        Ohio
# 1345        1352         Laura Berg  1975-01-06  Santa Fe Springs  California
#
#      born_country          NOC_x  height_cm  weight_kg   died_date first_name  \
# 54            USA  Great Britain      177.0       64.0         NaN    Monique
# 960           USA         Mexico      170.0       60.0         NaN    Xóchitl
# 961           USA         Mexico      160.0       54.0         NaN   Angélica
# 1231          USA         Canada        NaN        NaN  1986-02-20       Bert
# 1345          USA  United States      168.0       61.0         NaN      Laura
#
# ...

# %%
result.head()
# Out:
#      year    type discipline                     event                     as  \
# 0  1912.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 1  1912.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
# 2  1920.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 3  1920.0  Summer     Tennis  Doubles, Mixed (Olympic)  Jean-François Blanchy
# 4  1920.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
#
#    athlete_id  noc             team  place   tied medal
# 0           1  FRA             None   17.0   True  None
# 1           1  FRA   Jean Montariol    NaN  False  None
# 2           1  FRA             None   32.0   True  None
# 3           1  FRA  Jeanne Vaussard    8.0   True  None
# 4           1  FRA  Jacques Brugnon    4.0  False  None

# %%
combined_df = pd.merge(result,bios_new,on='athlete_id', how='left')

# %%
combined_df.head()
# Out:
#      year    type discipline                     event                     as  \
# 0  1912.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 1  1912.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
# 2  1920.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 3  1920.0  Summer     Tennis  Doubles, Mixed (Olympic)  Jean-François Blanchy
# 4  1920.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
#
#    athlete_id  noc             team  place   tied  ... height_cm weight_kg  \
# 0           1  FRA             None   17.0   True  ...       NaN       NaN
# 1           1  FRA   Jean Montariol    NaN  False  ...       NaN       NaN
# 2           1  FRA             None   32.0   True  ...       NaN       NaN
# 3           1  FRA  Jeanne Vaussard    8.0   True  ...       NaN       NaN
# 4           1  FRA  Jacques Brugnon    4.0  False  ...       NaN       NaN
#
# ...

# %%
coffee
# Out:
#                  Day Coffee Type  Units Sold  new_price  revenue
# Day
# Monday        Monday    Espresso          25       3.99    99.75
# Monday        Monday       Latte          10       5.99    59.90
# Tuesday      Tuesday    Espresso          10       3.99    39.90
# Tuesday      Tuesday       Latte          10       5.99    59.90
# Wednesday  Wednesday    Espresso          35       3.99   139.65
# Wednesday  Wednesday       Latte          25       5.99   149.75
# Thursday    Thursday    Espresso          40       3.99   159.60
# Thursday    Thursday       Latte          30       5.99   179.70
# Friday        Friday    Espresso          45       3.99   179.55
# Friday        Friday       Latte          35       5.99   209.65
# Saturday    Saturday    Espresso          45       3.99   179.55
# Saturday    Saturday       Latte          35       5.99   209.65
# Sunday        Sunday    Espresso          45       3.99   179.55
# ...

# %%
# Option 2: If index is named (like "Day"), reset it
coffee = coffee.reset_index(drop=True)

# %%
coffee.loc[[2,3], 'Units Sold'] = np.nan

# %%
coffee.loc[[0,2], 'Units Sold'] = 15

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  new_price  revenue
# 0      Monday    Espresso        15.0       3.99    99.75
# 1      Monday       Latte         NaN       5.99    59.90
# 2     Tuesday    Espresso        15.0       3.99    39.90
# 3     Tuesday       Latte         NaN       5.99    59.90
# 4   Wednesday    Espresso        35.0       3.99   139.65
# 5   Wednesday       Latte        25.0       5.99   149.75
# 6    Thursday    Espresso        40.0       3.99   159.60
# 7    Thursday       Latte        30.0       5.99   179.70
# 8      Friday    Espresso        45.0       3.99   179.55
# 9      Friday       Latte        35.0       5.99   209.65
# 10   Saturday    Espresso        45.0       3.99   179.55
# 11   Saturday       Latte        35.0       5.99   209.65
# 12     Sunday    Espresso        45.0       3.99   179.55
# 13     Sunday       Latte        35.0       5.99   209.65

# %%
coffee['Units Sold'].interpolate()
# Out:
# 0     15.0
# 1     15.0
# 2     15.0
# 3     25.0
# 4     35.0
# 5     25.0
# 6     40.0
# 7     30.0
# 8     45.0
# 9     35.0
# 10    45.0
# 11    35.0
# 12    45.0
# 13    35.0
# Name: Units Sold, dtype: float64

# %%
coffee.dropna()
# Out:
#           Day Coffee Type  Units Sold  new_price  revenue
# 0      Monday    Espresso        15.0       3.99    99.75
# 2     Tuesday    Espresso        15.0       3.99    39.90
# 4   Wednesday    Espresso        35.0       3.99   139.65
# 5   Wednesday       Latte        25.0       5.99   149.75
# 6    Thursday    Espresso        40.0       3.99   159.60
# 7    Thursday       Latte        30.0       5.99   179.70
# 8      Friday    Espresso        45.0       3.99   179.55
# 9      Friday       Latte        35.0       5.99   209.65
# 10   Saturday    Espresso        45.0       3.99   179.55
# 11   Saturday       Latte        35.0       5.99   209.65
# 12     Sunday    Espresso        45.0       3.99   179.55
# 13     Sunday       Latte        35.0       5.99   209.65

# %%
coffee[coffee['Units Sold'].isna()]
# Out:
#        Day Coffee Type  Units Sold  new_price  revenue
# 1   Monday       Latte         NaN       5.99     59.9
# 3  Tuesday       Latte         NaN       5.99     59.9

# %%
coffee[coffee['Units Sold'].notna()]
# Out:
#           Day Coffee Type  Units Sold  new_price  revenue
# 0      Monday    Espresso        15.0       3.99    99.75
# 2     Tuesday    Espresso        15.0       3.99    39.90
# 4   Wednesday    Espresso        35.0       3.99   139.65
# 5   Wednesday       Latte        25.0       5.99   149.75
# 6    Thursday    Espresso        40.0       3.99   159.60
# 7    Thursday       Latte        30.0       5.99   179.70
# 8      Friday    Espresso        45.0       3.99   179.55
# 9      Friday       Latte        35.0       5.99   209.65
# 10   Saturday    Espresso        45.0       3.99   179.55
# 11   Saturday       Latte        35.0       5.99   209.65
# 12     Sunday    Espresso        45.0       3.99   179.55
# 13     Sunday       Latte        35.0       5.99   209.65

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date     first_name born_datetime  born_year height_category
# 0  1960-10-02  Jean-François    1886-12-12     1886.0            Tall
# ...

# %%
bios['born_city'].value_counts().head(10)
# Out:
# born_city
# Budapest                  1378
# Moskva (Moscow)            883
# Oslo                       708
# Stockholm                  629
# Praha (Prague)             600
# Toronto                    579
# Wien (Vienna)              547
# Buenos Aires               538
# København (Copenhagen)     523
# Sydney                     497
# Name: count, dtype: int64

# %%
bios[bios['born_country'] == 'USA'] ['born_region'].value_counts()
# Out:
# born_region
# California              1634
# New York                 990
# Illinois                 585
# Pennsylvania             530
# Massachusetts            530
# New Jersey               381
# Texas                    368
# Minnesota                365
# Ohio                     328
# Michigan                 319
# Washington               240
# Florida                  235
# Wisconsin                209
# Colorado                 207
# Connecticut              156
# Indiana                  150
# Oregon                   132
# Georgia                  129
# Virginia                 121
# Maryland                 117
# District of Columbia     107
# Iowa                     102
# Hawaiʻi                   95
# Kansas                    94
# Oklahoma                  93
# Louisiana                 92
# Utah                      91
# Missouri                  91
# North Carolina            86
# Arizona                   83
# New Hampshire             83
# ...

# %%
coffee['Units Sold'] = coffee['Units Sold'].interpolate()

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  new_price  revenue
# 0      Monday    Espresso        15.0       3.99    99.75
# 1      Monday       Latte        15.0       5.99    59.90
# 2     Tuesday    Espresso        15.0       3.99    39.90
# 3     Tuesday       Latte        25.0       5.99    59.90
# 4   Wednesday    Espresso        35.0       3.99   139.65
# 5   Wednesday       Latte        25.0       5.99   149.75
# 6    Thursday    Espresso        40.0       3.99   159.60
# 7    Thursday       Latte        30.0       5.99   179.70
# 8      Friday    Espresso        45.0       3.99   179.55
# 9      Friday       Latte        35.0       5.99   209.65
# 10   Saturday    Espresso        45.0       3.99   179.55
# 11   Saturday       Latte        35.0       5.99   209.65
# 12     Sunday    Espresso        45.0       3.99   179.55
# 13     Sunday       Latte        35.0       5.99   209.65

# %%
coffee.groupby(['Coffee Type'])['Units Sold'].sum()
# Out:
# Coffee Type
# Espresso    240.0
# Latte       200.0
# Name: Units Sold, dtype: float64

# %%
coffee.groupby(['Coffee Type'])['Units Sold'].mean()
# Out:
# Coffee Type
# Espresso    34.285714
# Latte       28.571429
# Name: Units Sold, dtype: float64

# %%
coffee.groupby(['Coffee Type']).agg({'Units Sold': 'sum', 'new_price':'mean'})
# Out:
#              Units Sold  new_price
# Coffee Type
# Espresso          240.0       3.99
# Latte             200.0       5.99

# %%
pivot = coffee.pivot(columns= 'Coffee Type', index='Day', values='revenue')

# %%
pivot.plot(kind='line')
# Out:
# <Axes: xlabel='Day'>

# %%
pivot.loc['Monday', 'Latte']
# Out:
# 59.900000000000006

# %%
pivot.sum()
# Out:
# Coffee Type
# Espresso     977.55
# Latte       1078.20
# dtype: float64

# %%
pivot.sum(axis=1)
# Out:
# Day
# Friday       389.20
# Monday       159.65
# Saturday     389.20
# Sunday       389.20
# Thursday     339.30
# Tuesday       99.80
# Wednesday    289.40
# dtype: float64

# %%
bios['born_date'] = pd.to_datetime(bios['born_date'])

bios.groupby(bios['born_date'].dt.year)['name'].count().reset_index().sort_values('name', ascending=False)
# Out:
#      born_date  name
# 139     1972.0  2231
# 152     1985.0  2227
# 140     1973.0  2216
# 138     1971.0  2205
# 137     1970.0  2174
# ..         ...   ...
# 5       1838.0     1
# 4       1837.0     1
# 3       1836.0     1
# 2       1833.0     1
# 176     2009.0     1
#
# [177 rows x 2 columns]

# %%
bios['born_date'] = pd.to_datetime(bios['born_date'])
bios['month_born'] = bios['born_date'].dt.month
bios['year_born'] = bios['born_date'].dt.year

bios.groupby([bios['year_born'],bios['month_born']])['name'].count().reset_index().sort_values('name', ascending=False)
# Out:
#       year_born  month_born  name
# 1437     1970.0         1.0   239
# 1461     1972.0         1.0   229
# 1629     1986.0         1.0   227
# 1497     1975.0         1.0   227
# 1617     1985.0         1.0   225
# ...         ...         ...   ...
# 95       1857.0         5.0     1
# 96       1857.0         7.0     1
# 97       1857.0         8.0     1
# 98       1857.0         9.0     1
# 1884     2009.0         1.0     1
#
# [1885 rows x 3 columns]

# %%
coffee['yesterday_revenue'] = coffee['revenue'].shift(1)

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  new_price  revenue  yesterday_revenue
# 0      Monday    Espresso        15.0       3.99    99.75                NaN
# 1      Monday       Latte        15.0       5.99    59.90              99.75
# 2     Tuesday    Espresso        15.0       3.99    39.90              59.90
# 3     Tuesday       Latte        25.0       5.99    59.90              39.90
# 4   Wednesday    Espresso        35.0       3.99   139.65              59.90
# 5   Wednesday       Latte        25.0       5.99   149.75             139.65
# 6    Thursday    Espresso        40.0       3.99   159.60             149.75
# 7    Thursday       Latte        30.0       5.99   179.70             159.60
# 8      Friday    Espresso        45.0       3.99   179.55             179.70
# 9      Friday       Latte        35.0       5.99   209.65             179.55
# 10   Saturday    Espresso        45.0       3.99   179.55             209.65
# ...

# %%
coffee['pct_change'] = coffee['revenue']/coffee['yesterday_revenue'] *100

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  new_price  revenue  yesterday_revenue  \
# 0      Monday    Espresso        15.0       3.99    99.75                NaN
# 1      Monday       Latte        15.0       5.99    59.90              99.75
# 2     Tuesday    Espresso        15.0       3.99    39.90              59.90
# 3     Tuesday       Latte        25.0       5.99    59.90              39.90
# 4   Wednesday    Espresso        35.0       3.99   139.65              59.90
# 5   Wednesday       Latte        25.0       5.99   149.75             139.65
# 6    Thursday    Espresso        40.0       3.99   159.60             149.75
# 7    Thursday       Latte        30.0       5.99   179.70             159.60
# 8      Friday    Espresso        45.0       3.99   179.55             179.70
# 9      Friday       Latte        35.0       5.99   209.65             179.55
# 10   Saturday    Espresso        45.0       3.99   179.55             209.65
# ...

# %%
bios['height_rank'] = bios['height_cm'].rank()

# %%
bios
# Out:
#         athlete_id                   name  born_date        born_city  \
# 0                1  Jean-François Blanchy 1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch 1969-04-01           Meulan
# 2                3           Jean Borotra 1898-08-13         Biarritz
# 3                4        Jacques Brugnon 1895-05-11      Paris VIIIe
# 4                5           Albert Canet 1878-04-17       Wandsworth
# ...            ...                    ...        ...              ...
# 145495      149222      Polina Luchnikova 2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva 1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova 1998-05-08           Kotlas
# 145498      149225         André Foussard 1899-05-19            Niort
# 145499      149814          Bill Phillips 1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# ...

# %%
bios.sort_values(['height_rank'],ascending=False)
# Out:
#         athlete_id                   name  born_date           born_city  \
# 89070        89782               Yao Ming 1980-09-12      Xuhui District
# 5781          5804         Tommy Burleson 1952-02-24           Crossnore
# 6978          7013        Arvydas Sabonis 1964-12-19              Kaunas
# 89075        89787         Roberto Dueñas 1975-11-01              Madrid
# 120266      122147           Zhang Zhaoxu 1987-11-18             Binzhou
# ...            ...                    ...        ...                 ...
# 145490      149217            Sin Ye-Chan 1995-06-13                 NaN
# 145491      149218          Matthew Wepke 1989-12-05                 NaN
# 145492      149219  Carlos García-Ordóñez 1927-04-24  La Habana (Havana)
# 145493      149220     Landysh Falyakhova 1998-08-31    Dva Polya Artash
# 145499      149814          Bill Phillips 1913-07-15        Dulwich Hill
#
#                  born_region born_country                         NOC  \
# ...

# %%
bios['height_rank'] = bios['height_cm'].rank(ascending=False)

# %%
bios
# Out:
#         athlete_id                   name  born_date        born_city  \
# 0                1  Jean-François Blanchy 1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch 1969-04-01           Meulan
# 2                3           Jean Borotra 1898-08-13         Biarritz
# 3                4        Jacques Brugnon 1895-05-11      Paris VIIIe
# 4                5           Albert Canet 1878-04-17       Wandsworth
# ...            ...                    ...        ...              ...
# 145495      149222      Polina Luchnikova 2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva 1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova 1998-05-08           Kotlas
# 145498      149225         André Foussard 1899-05-19            Niort
# 145499      149814          Bill Phillips 1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# ...

# %%
coffee['cumulative_revenue'] = coffee['revenue'].cumsum()

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  new_price  revenue  yesterday_revenue  \
# 0      Monday    Espresso        15.0       3.99    99.75                NaN
# 1      Monday       Latte        15.0       5.99    59.90              99.75
# 2     Tuesday    Espresso        15.0       3.99    39.90              59.90
# 3     Tuesday       Latte        25.0       5.99    59.90              39.90
# 4   Wednesday    Espresso        35.0       3.99   139.65              59.90
# 5   Wednesday       Latte        25.0       5.99   149.75             139.65
# 6    Thursday    Espresso        40.0       3.99   159.60             149.75
# 7    Thursday       Latte        30.0       5.99   179.70             159.60
# 8      Friday    Espresso        45.0       3.99   179.55             179.70
# 9      Friday       Latte        35.0       5.99   209.65             179.55
# 10   Saturday    Espresso        45.0       3.99   179.55             209.65
# ...

# %%
latte = coffee[coffee['Coffee Type'] == 'Latte'].copy()
latte['3days'] = latte['Units Sold'].rolling(3).sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 latte = coffee[coffee['Coffee Type'] == 'Latte'].copy()
#       2 latte['3days'] = latte['Units Sold'].rolling(3).sum()
#
# NameError: name 'coffee' is not defined

# %%
latte
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 latte
#
# NameError: name 'latte' is not defined

# %%
import pandas as pd

# %%
df1 = pd.DataFrame({'Name': ['Alice', 'Bob'], 'Age': [25, 30]})
df2 = pd.DataFrame({'Name': ['Charlie', 'David'], 'Age': [35, 40]})

df_combined = pd.concat([df1, df2], ignore_index=True)
print(df_combined)
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35
# 3    David   40
